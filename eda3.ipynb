# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
path1='/content/drive/MyDrive/Classroom/features.csv'
path2='/content/drive/MyDrive/Classroom/stores.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1=pd.read_csv(path1)
df1.head(10)
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
# 5      1  2010-03-12        57.79       2.667        NaN        NaN
# 6      1  2010-03-19        54.58       2.720        NaN        NaN
# 7      1  2010-03-26        51.45       2.732        NaN        NaN
# 8      1  2010-04-02        62.27       2.719        NaN        NaN
# 9      1  2010-04-09        65.86       2.770        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# ...

# %%
df2=pd.read_csv(path2)
df2.head(10)
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875
# 5      6    A  202505
# 6      7    B   70713
# 7      8    A  155078
# 8      9    B  125833
# 9     10    B  126512

# %%
merged = pd.merge(df1, df2, on='Store', how='left')
merged.to_csv("merged.csv", index=False)

# %%
merged.head(10)
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
# 5      1  2010-03-12        57.79       2.667        NaN        NaN
# 6      1  2010-03-19        54.58       2.720        NaN        NaN
# 7      1  2010-03-26        51.45       2.732        NaN        NaN
# 8      1  2010-04-02        62.27       2.719        NaN        NaN
# 9      1  2010-04-09        65.86       2.770        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106     False  NaN
# ...

# %%
merged.head(100)
# Out:
#     Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0       1  2010-02-05        42.31       2.572        NaN        NaN
# 1       1  2010-02-12        38.51       2.548        NaN        NaN
# 2       1  2010-02-19        39.93       2.514        NaN        NaN
# 3       1  2010-02-26        46.63       2.561        NaN        NaN
# 4       1  2010-03-05        46.50       2.625        NaN        NaN
# ..    ...         ...          ...         ...        ...        ...
# 95      1  2011-12-02        48.91       3.172    5629.51      68.00
# 96      1  2011-12-09        43.93       3.158    4640.65      19.00
# 97      1  2011-12-16        51.63       3.159    5011.32      67.00
# 98      1  2011-12-23        47.96       3.112    2725.36      40.48
# 99      1  2011-12-30        44.55       3.129    5762.10   46011.38
#
#     MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday Type  \
# ...

# %%
merged.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# Type               0
# Size               0
# dtype: int64

# %%
merged.shape
# Out:
# (8235, 14)

# %%
df2.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
merged['Temperature'] = pd.to_numeric(merged['Temperature'], errors='coerce')
median_temp = merged['Temperature'].median()
merged['Temperature'] = merged['Temperature'].fillna(median_temp)

# %%
merged.drop_duplicates(keep='first')
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05          NaN       2.572        NaN        NaN
# 1         1  2010-02-12          NaN       2.548        NaN        NaN
# 2         1  2010-02-19          NaN       2.514        NaN        NaN
# 3         1  2010-02-26          NaN       2.561        NaN        NaN
# 4         1  2010-03-05          NaN       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8230     41         NaN          NaN         NaN        NaN        NaN
# 8231     42         NaN          NaN         NaN        NaN        NaN
# 8232     43         NaN          NaN         NaN        NaN        NaN
# 8233     44         NaN          NaN         NaN        NaN        NaN
# 8234     45         NaN          NaN         NaN        NaN        NaN
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday  \
# ...

# %%
merged.duplicated().sum()
# Out:
# np.int64(0)

# %%
merged = merged.reset_index(drop=True)

# %%
#outliners

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(merged['Temperature'])
# Out:
# <Axes: ylabel='Temperature'>
